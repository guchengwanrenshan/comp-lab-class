# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#load mdtraj
import mdtraj as md
# Out:
# /home/lz2826/.local/lib/python3.8/site-packages/numpy/core/getlimits.py:500: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/lz2826/.local/lib/python3.8/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# /home/lz2826/.local/lib/python3.8/site-packages/numpy/core/getlimits.py:500: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/lz2826/.local/lib/python3.8/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)

# %%
df1= pd.read_csv('./SOD_msd.xvg',skiprows=20,sep='\s+',header=None)
df1.columns = [ "Time (ps)","S" ]
df1
# Out:
#        Time (ps)           S
# 0            0.0    0.000000
# 1        10000.0    0.331676
# 2        20000.0    0.658136
# 3        30000.0    0.975252
# 4        40000.0    1.289860
# ...          ...         ...
# 996    9960000.0  270.578000
# 997    9970000.0  269.824000
# 998    9980000.0  270.433000
# 999    9990000.0  273.552000
# 1000  10000000.0  277.363000
#
# [1001 rows x 2 columns]

# %%
df2= pd.read_csv('./CLA_msd.xvg',skiprows=20,sep='\s+',header=None)
df2.columns = [ "Time (ps)","CLA" ]
df2
# Out:
#        Time (ps)         CLA
# 0            0.0    0.000000
# 1        10000.0    0.382922
# 2        20000.0    0.755440
# 3        30000.0    1.114620
# 4        40000.0    1.465510
# ...          ...         ...
# 996    9960000.0  211.643000
# 997    9970000.0  213.853000
# 998    9980000.0  213.435000
# 999    9990000.0  210.285000
# 1000  10000000.0  211.372000
#
# [1001 rows x 2 columns]

# %%
df3= pd.read_csv('./Water_msd.xvg',skiprows=20,sep='\s+',header=None)
df3.columns = [ "Time (ps)","water" ]
df3
# Out:
#        Time (ps)       water
# 0            0.0    0.000000
# 1        10000.0    0.555861
# 2        20000.0    1.106810
# 3        30000.0    1.647900
# 4        40000.0    2.185880
# ...          ...         ...
# 996    9960000.0  402.354000
# 997    9970000.0  402.916000
# 998    9980000.0  403.739000
# 999    9990000.0  404.881000
# 1000  10000000.0  406.709000
#
# [1001 rows x 2 columns]

# %%
plt.plot(df1["Time (ps)"],df1["S"], 'r',linewidth=3,linestyle='dashed',label='S')
plt.plot(df2["Time (ps)"],df2["CLA"], 'b',linewidth=3,linestyle='dashed',label='CLA')
plt.plot(df3["Time (ps)"],df3["water"], 'g',linewidth=3,linestyle='dashed',label='water_O')
plt.legend()
plt.show()
